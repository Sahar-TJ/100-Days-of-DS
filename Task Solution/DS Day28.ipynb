# %% [markdown]
# # Day 28 of 100 Days of Data Science
#
# ---
# ## Stats - Relationship Measures and Distribution

# %% [markdown]
# __Causation:__ Causing an event to happen.
# __Correlation:__ Attributes showing similarity to each other. it always be between -1 and +1. Tells how strongly they are related to each other.

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\user\Desktop\100daysds\For_Cor_Cov.csv')
print(data.head())
# Out:
#    Input  Output
# 0   1000      10
# 1   1074      16
# 2   1125      21
# 3   1197      26
# 4   1275      31

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data.cov()
# Out:
#                Input         Output
# Input   3.666234e+06  410515.140707
# Output  4.105151e+05   45988.313030

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data.corr()
# Out:
#            Input    Output
# Input   1.000000  0.999759
# Output  0.999759  1.000000

# %%
data['Input'] = data['Input']*100

# %%
data.head()
# Out:
#     Input  Output
# 0  100000      10
# 1  107400      16
# 2  112500      21
# 3  119700      26
# 4  127500      31

# %%
data.cov()
# Out:
#                Input        Output
# Input   3.666234e+10  4.105151e+07
# Output  4.105151e+07  4.598831e+04

# %%
data.corr()
# Out:
#            Input    Output
# Input   1.000000  0.999759
# Output  0.999759  1.000000

# %% [markdown]
# __Probability Distributions__ -  A probability distribution is a mathematical function that gives the probabilities of occurrence of different possible outcomes for an experiment
# - Normal Distribution - Normal distribution describes continuous data which have a symmetric distribution
# - Uniform Distribution - Same Probability
# - Binomial Distribution - Distribution of binary data from a finite sample

# %% [markdown]
# ## Thank You!
